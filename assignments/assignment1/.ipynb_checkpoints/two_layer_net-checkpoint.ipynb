# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.68027207459e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12 f(xi)
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 1.79634085384e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W2 max relative error: 3.440708e-09
# b2 max relative error: 3.865070e-11
# W1 max relative error: 3.561318e-09
# b1 max relative error: 1.555470e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.0171496079387

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302968
# iteration 100 / 1000: loss 2.302637
# iteration 200 / 1000: loss 2.298608
# iteration 300 / 1000: loss 2.270553
# iteration 400 / 1000: loss 2.202822
# iteration 500 / 1000: loss 2.160027
# iteration 600 / 1000: loss 2.076044
# iteration 700 / 1000: loss 2.042697
# iteration 800 / 1000: loss 2.002948
# iteration 900 / 1000: loss 1.964609
# Validation accuracy:  0.285

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 
best_acc = 0
best_hidden_size = 0
best_learning_rate = 0
best_reg = 0
best_num_iter = 0
#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################

input_size = 32 * 32 * 3

hidden_sizes = [100, 150, 500]
learning_rates = [1e-3, 5e-3, 1e-4]
regs = [0.1, 0.2, 0.25, 0.4]
num_iters = [100, 500, 1000, 1500]
num_classes = 10

# Train the network
for hidden_size in hidden_sizes:
    for learning_rate in learning_rates:
        for reg in regs:
            for num_iter in num_iters:
                net = TwoLayerNet(input_size, hidden_size, num_classes)
                stats = net.train(X_train, y_train, X_val, y_val,
                                  num_iters=num_iter, batch_size=200,
                                  learning_rate=learning_rate, 
                                  learning_rate_decay=0.95, reg=reg,
                                  verbose=True);

                # Predict on the validation set
                acc = stats['val_acc_history'][-1]
                print('for hidden_size: %i, learning_rate: %e, regularisation strength: %f, and epochs: %i, the validation accuracy is: %f' %(hidden_size, learning_rate, reg, num_iter, acc))
                
                if acc > best_acc:
                    print('new best network!')
                    best_net = net
                    best_acc = acc
                    best_hidden_size = hidden_size
                    best_learning_rate = learning_rate
                    best_reg = reg
                    best_num_iter = num_iter
                    
print('Best net: for hidden_size: %i, learning_rate: %e, regularisation strength: %f, and epochs: %i, the validation accuracy is: %f' %(best_hidden_size, best_learning_rate, best_reg, best_num_iter, best_acc))

#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Out:
# iteration 0 / 100: loss 2.302902
# for hidden_size: 100, learning_rate: 1.000000e-03, regularisation strength: 0.100000, and epochs: 100, the validation accuracy is: 0.137000
# new best network!
# iteration 0 / 500: loss 2.302902
# iteration 100 / 500: loss 1.908833
# iteration 200 / 500: loss 1.745249
# iteration 300 / 500: loss 1.776291
# iteration 400 / 500: loss 1.640876
# for hidden_size: 100, learning_rate: 1.000000e-03, regularisation strength: 0.100000, and epochs: 500, the validation accuracy is: 0.446000
# new best network!
# iteration 0 / 1000: loss 2.302873
# iteration 100 / 1000: loss 1.954742
# iteration 200 / 1000: loss 1.864701
# iteration 300 / 1000: loss 1.721451
# iteration 400 / 1000: loss 1.654417
# iteration 500 / 1000: loss 1.504139
# iteration 600 / 1000: loss 1.449186
# iteration 700 / 1000: loss 1.464881
# iteration 800 / 1000: loss 1.491437
# iteration 900 / 1000: loss 1.385199
# for hidden_size: 100, learning_rate: 1.000000e-03, regularisation strength: 0.100000, and epochs: 1000, the validation accuracy is: 0.475000
# new best network!
# iteration 0 / 1500: loss 2.302904
# iteration 100 / 1500: loss 1.955853
# iteration 200 / 1500: loss 1.839594
# iteration 300 / 1500: loss 1.560714
# iteration 400 / 1500: loss 1.624920
# iteration 500 / 1500: loss 1.529420
# iteration 600 / 1500: loss 1.583783
# iteration 700 / 1500: loss 1.429817
# iteration 800 / 1500: loss 1.518460
# iteration 900 / 1500: loss 1.525915
# iteration 1000 / 1500: loss 1.511466
# iteration 1100 / 1500: loss 1.448490
# iteration 1200 / 1500: loss 1.400989
# iteration 1300 / 1500: loss 1.349539
# iteration 1400 / 1500: loss 1.451197
# for hidden_size: 100, learning_rate: 1.000000e-03, regularisation strength: 0.100000, and epochs: 1500, the validation accuracy is: 0.494000
# new best network!
# iteration 0 / 100: loss 2.303188
# for hidden_size: 100, learning_rate: 1.000000e-03, regularisation strength: 0.200000, and epochs: 100, the validation accuracy is: 0.151000
# iteration 0 / 500: loss 2.303158
# iteration 100 / 500: loss 1.894886
# iteration 200 / 500: loss 1.892778
# iteration 300 / 500: loss 1.694426
# iteration 400 / 500: loss 1.618699
# for hidden_size: 100, learning_rate: 1.000000e-03, regularisation strength: 0.200000, and epochs: 500, the validation accuracy is: 0.442000
# iteration 0 / 1000: loss 2.303194
# iteration 100 / 1000: loss 1.986774
# iteration 200 / 1000: loss 1.817825
# iteration 300 / 1000: loss 1.762380
# iteration 400 / 1000: loss 1.753126
# iteration 500 / 1000: loss 1.653293
# iteration 600 / 1000: loss 1.638607
# iteration 700 / 1000: loss 1.585203
# iteration 800 / 1000: loss 1.591740
# iteration 900 / 1000: loss 1.476040
# for hidden_size: 100, learning_rate: 1.000000e-03, regularisation strength: 0.200000, and epochs: 1000, the validation accuracy is: 0.478000
# iteration 0 / 1500: loss 2.303195
# iteration 100 / 1500: loss 1.812854
# iteration 200 / 1500: loss 1.765612
# iteration 300 / 1500: loss 1.687597
# iteration 400 / 1500: loss 1.503142
# iteration 500 / 1500: loss 1.665949
# iteration 600 / 1500: loss 1.641905
# iteration 700 / 1500: loss 1.424023
# iteration 800 / 1500: loss 1.653918
# iteration 900 / 1500: loss 1.471858
# iteration 1000 / 1500: loss 1.395459
# iteration 1100 / 1500: loss 1.402143
# iteration 1200 / 1500: loss 1.513210
# iteration 1300 / 1500: loss 1.509789
# iteration 1400 / 1500: loss 1.478105
# for hidden_size: 100, learning_rate: 1.000000e-03, regularisation strength: 0.200000, and epochs: 1500, the validation accuracy is: 0.497000
# new best network!
# iteration 0 / 100: loss 2.303346
# for hidden_size: 100, learning_rate: 1.000000e-03, regularisation strength: 0.250000, and epochs: 100, the validation accuracy is: 0.174000
# iteration 0 / 500: loss 2.303357
# iteration 100 / 500: loss 1.923264
# iteration 200 / 500: loss 1.766857
# iteration 300 / 500: loss 1.760581
# iteration 400 / 500: loss 1.588525
# for hidden_size: 100, learning_rate: 1.000000e-03, regularisation strength: 0.250000, and epochs: 500, the validation accuracy is: 0.444000
# iteration 0 / 1000: loss 2.303352
# iteration 100 / 1000: loss 2.021567
# iteration 200 / 1000: loss 1.751339
# iteration 300 / 1000: loss 1.785124
# iteration 400 / 1000: loss 1.594517
# iteration 500 / 1000: loss 1.538017
# iteration 600 / 1000: loss 1.573488
# iteration 700 / 1000: loss 1.473743
# iteration 800 / 1000: loss 1.523499
# iteration 900 / 1000: loss 1.314312
# for hidden_size: 100, learning_rate: 1.000000e-03, regularisation strength: 0.250000, and epochs: 1000, the validation accuracy is: 0.469000
# iteration 0 / 1500: loss 2.303402
# iteration 100 / 1500: loss 1.906573
# iteration 200 / 1500: loss 1.721391
# iteration 300 / 1500: loss 1.629989
# iteration 400 / 1500: loss 1.611837
# iteration 500 / 1500: loss 1.591600
# iteration 600 / 1500: loss 1.540753
# iteration 700 / 1500: loss 1.526924
# iteration 800 / 1500: loss 1.586352
# iteration 900 / 1500: loss 1.497940
# iteration 1000 / 1500: loss 1.488172
# iteration 1100 / 1500: loss 1.598734
# iteration 1200 / 1500: loss 1.493106
# iteration 1300 / 1500: loss 1.407061
# iteration 1400 / 1500: loss 1.438421
# for hidden_size: 100, learning_rate: 1.000000e-03, regularisation strength: 0.250000, and epochs: 1500, the validation accuracy is: 0.487000
# iteration 0 / 100: loss 2.303825
# for hidden_size: 100, learning_rate: 1.000000e-03, regularisation strength: 0.400000, and epochs: 100, the validation accuracy is: 0.142000
# iteration 0 / 500: loss 2.303818
# iteration 100 / 500: loss 1.882520
# iteration 200 / 500: loss 1.727247
# iteration 300 / 500: loss 1.768851
# iteration 400 / 500: loss 1.538971
# for hidden_size: 100, learning_rate: 1.000000e-03, regularisation strength: 0.400000, and epochs: 500, the validation accuracy is: 0.449000
# iteration 0 / 1000: loss 2.303853
# iteration 100 / 1000: loss 2.001180
# iteration 200 / 1000: loss 1.705621
# iteration 300 / 1000: loss 1.699741
# iteration 400 / 1000: loss 1.645484
# iteration 500 / 1000: loss 1.538621
# iteration 600 / 1000: loss 1.415510
# iteration 700 / 1000: loss 1.442797
# iteration 800 / 1000: loss 1.661678
# iteration 900 / 1000: loss 1.649356
# for hidden_size: 100, learning_rate: 1.000000e-03, regularisation strength: 0.400000, and epochs: 1000, the validation accuracy is: 0.459000
# iteration 0 / 1500: loss 2.303882
# iteration 100 / 1500: loss 1.995948
# iteration 200 / 1500: loss 1.804342
# iteration 300 / 1500: loss 1.663549
# iteration 400 / 1500: loss 1.637718
# iteration 500 / 1500: loss 1.727809
# iteration 600 / 1500: loss 1.492955
# iteration 700 / 1500: loss 1.584407
# iteration 800 / 1500: loss 1.645752
# iteration 900 / 1500: loss 1.447711
# iteration 1000 / 1500: loss 1.563767
# iteration 1100 / 1500: loss 1.513129
# iteration 1200 / 1500: loss 1.486697
# iteration 1300 / 1500: loss 1.453825
# iteration 1400 / 1500: loss 1.482254
# for hidden_size: 100, learning_rate: 1.000000e-03, regularisation strength: 0.400000, and epochs: 1500, the validation accuracy is: 0.483000
# iteration 0 / 100: loss 2.302895
# /home/nfriedrich/repos/CS231n_CNNs/assignments/assignment1/cs231n/classifiers/neural_net.py:108: RuntimeWarning: divide by zero encountered in log
#   soft_max = -np.log(prob_correct_y/sum_exp_scores)
# /home/nfriedrich/repos/CS231n_CNNs/assignments/assignment1/cs231n/classifiers/neural_net.py:101: RuntimeWarning: overflow encountered in exp
#   exp_scores = np.exp(scores)
# /home/nfriedrich/repos/CS231n_CNNs/assignments/assignment1/cs231n/classifiers/neural_net.py:108: RuntimeWarning: invalid value encountered in true_divide
#   soft_max = -np.log(prob_correct_y/sum_exp_scores)
# /home/nfriedrich/repos/CS231n_CNNs/assignments/assignment1/cs231n/classifiers/neural_net.py:127: RuntimeWarning: invalid value encountered in true_divide
#   dscores = exp_scores/sum_exp_scores.reshape(num_train, 1)
# for hidden_size: 100, learning_rate: 5.000000e-03, regularisation strength: 0.100000, and epochs: 100, the validation accuracy is: 0.198000
# iteration 0 / 500: loss 2.302891
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# for hidden_size: 100, learning_rate: 5.000000e-03, regularisation strength: 0.100000, and epochs: 500, the validation accuracy is: 0.087000
# iteration 0 / 1000: loss 2.302893
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# for hidden_size: 100, learning_rate: 5.000000e-03, regularisation strength: 0.100000, and epochs: 1000, the validation accuracy is: 0.087000
# iteration 0 / 1500: loss 2.302906
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# for hidden_size: 100, learning_rate: 5.000000e-03, regularisation strength: 0.100000, and epochs: 1500, the validation accuracy is: 0.087000
# iteration 0 / 100: loss 2.303158
# for hidden_size: 100, learning_rate: 5.000000e-03, regularisation strength: 0.200000, and epochs: 100, the validation accuracy is: 0.198000
# iteration 0 / 500: loss 2.303211
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# for hidden_size: 100, learning_rate: 5.000000e-03, regularisation strength: 0.200000, and epochs: 500, the validation accuracy is: 0.087000
# iteration 0 / 1000: loss 2.303191
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# for hidden_size: 100, learning_rate: 5.000000e-03, regularisation strength: 0.200000, and epochs: 1000, the validation accuracy is: 0.087000
# iteration 0 / 1500: loss 2.303217
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# for hidden_size: 100, learning_rate: 5.000000e-03, regularisation strength: 0.200000, and epochs: 1500, the validation accuracy is: 0.087000
# iteration 0 / 100: loss 2.303378
# for hidden_size: 100, learning_rate: 5.000000e-03, regularisation strength: 0.250000, and epochs: 100, the validation accuracy is: 0.195000
# iteration 0 / 500: loss 2.303377
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# for hidden_size: 100, learning_rate: 5.000000e-03, regularisation strength: 0.250000, and epochs: 500, the validation accuracy is: 0.087000
# iteration 0 / 1000: loss 2.303334
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# for hidden_size: 100, learning_rate: 5.000000e-03, regularisation strength: 0.250000, and epochs: 1000, the validation accuracy is: 0.087000
# iteration 0 / 1500: loss 2.303361
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# for hidden_size: 100, learning_rate: 5.000000e-03, regularisation strength: 0.250000, and epochs: 1500, the validation accuracy is: 0.087000
# iteration 0 / 100: loss 2.303823
# for hidden_size: 100, learning_rate: 5.000000e-03, regularisation strength: 0.400000, and epochs: 100, the validation accuracy is: 0.165000
# iteration 0 / 500: loss 2.303809
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# for hidden_size: 100, learning_rate: 5.000000e-03, regularisation strength: 0.400000, and epochs: 500, the validation accuracy is: 0.087000
# iteration 0 / 1000: loss 2.303836
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# for hidden_size: 100, learning_rate: 5.000000e-03, regularisation strength: 0.400000, and epochs: 1000, the validation accuracy is: 0.087000
# iteration 0 / 1500: loss 2.303806
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# for hidden_size: 100, learning_rate: 5.000000e-03, regularisation strength: 0.400000, and epochs: 1500, the validation accuracy is: 0.087000
# iteration 0 / 100: loss 2.302892
# for hidden_size: 100, learning_rate: 1.000000e-04, regularisation strength: 0.100000, and epochs: 100, the validation accuracy is: 0.127000
# iteration 0 / 500: loss 2.302892
# iteration 100 / 500: loss 2.302165
# iteration 200 / 500: loss 2.294946
# iteration 300 / 500: loss 2.242018
# iteration 400 / 500: loss 2.148886
# for hidden_size: 100, learning_rate: 1.000000e-04, regularisation strength: 0.100000, and epochs: 500, the validation accuracy is: 0.235000
# iteration 0 / 1000: loss 2.302888
# iteration 100 / 1000: loss 2.301641
# iteration 200 / 1000: loss 2.294259
# iteration 300 / 1000: loss 2.240821
# iteration 400 / 1000: loss 2.160954
# iteration 500 / 1000: loss 2.141229
# iteration 600 / 1000: loss 2.038435
# iteration 700 / 1000: loss 1.991037
# iteration 800 / 1000: loss 1.966879
# iteration 900 / 1000: loss 1.936510
# for hidden_size: 100, learning_rate: 1.000000e-04, regularisation strength: 0.100000, and epochs: 1000, the validation accuracy is: 0.296000
# iteration 0 / 1500: loss 2.302899
# iteration 100 / 1500: loss 2.301871
# iteration 200 / 1500: loss 2.294039
# iteration 300 / 1500: loss 2.244763
# iteration 400 / 1500: loss 2.153108
# iteration 500 / 1500: loss 2.081244
# iteration 600 / 1500: loss 2.077528
# iteration 700 / 1500: loss 2.087807
# iteration 800 / 1500: loss 2.047645
# iteration 900 / 1500: loss 1.908590
# iteration 1000 / 1500: loss 1.971859
# iteration 1100 / 1500: loss 1.927777
# iteration 1200 / 1500: loss 1.967775
# iteration 1300 / 1500: loss 1.908223
# iteration 1400 / 1500: loss 1.874282
# for hidden_size: 100, learning_rate: 1.000000e-04, regularisation strength: 0.100000, and epochs: 1500, the validation accuracy is: 0.330000
# iteration 0 / 100: loss 2.303207
# for hidden_size: 100, learning_rate: 1.000000e-04, regularisation strength: 0.200000, and epochs: 100, the validation accuracy is: 0.094000
# iteration 0 / 500: loss 2.303182
# iteration 100 / 500: loss 2.301996
# iteration 200 / 500: loss 2.292296
# iteration 300 / 500: loss 2.238724
# iteration 400 / 500: loss 2.224531
# for hidden_size: 100, learning_rate: 1.000000e-04, regularisation strength: 0.200000, and epochs: 500, the validation accuracy is: 0.232000
# iteration 0 / 1000: loss 2.303173
# iteration 100 / 1000: loss 2.302223
# iteration 200 / 1000: loss 2.288264
# iteration 300 / 1000: loss 2.233495
# iteration 400 / 1000: loss 2.180076
# iteration 500 / 1000: loss 2.153974
# iteration 600 / 1000: loss 2.091935
# iteration 700 / 1000: loss 2.007582
# iteration 800 / 1000: loss 1.956020
# iteration 900 / 1000: loss 1.875364
# for hidden_size: 100, learning_rate: 1.000000e-04, regularisation strength: 0.200000, and epochs: 1000, the validation accuracy is: 0.287000
# iteration 0 / 1500: loss 2.303199
# iteration 100 / 1500: loss 2.302407
# iteration 200 / 1500: loss 2.293178
# iteration 300 / 1500: loss 2.252825
# iteration 400 / 1500: loss 2.178231
# iteration 500 / 1500: loss 2.068021
# iteration 600 / 1500: loss 2.026582
# iteration 700 / 1500: loss 2.057920
# iteration 800 / 1500: loss 2.009628
# iteration 900 / 1500: loss 2.009041
# iteration 1000 / 1500: loss 1.939192
# iteration 1100 / 1500: loss 1.992793
# iteration 1200 / 1500: loss 1.904812
# iteration 1300 / 1500: loss 1.868218
# iteration 1400 / 1500: loss 1.769060
# for hidden_size: 100, learning_rate: 1.000000e-04, regularisation strength: 0.200000, and epochs: 1500, the validation accuracy is: 0.330000
# iteration 0 / 100: loss 2.303342
# for hidden_size: 100, learning_rate: 1.000000e-04, regularisation strength: 0.250000, and epochs: 100, the validation accuracy is: 0.097000
# iteration 0 / 500: loss 2.303380
# iteration 100 / 500: loss 2.302678
# iteration 200 / 500: loss 2.298254
# iteration 300 / 500: loss 2.258057
# iteration 400 / 500: loss 2.164311
# for hidden_size: 100, learning_rate: 1.000000e-04, regularisation strength: 0.250000, and epochs: 500, the validation accuracy is: 0.233000
# iteration 0 / 1000: loss 2.303379
# iteration 100 / 1000: loss 2.302567
# iteration 200 / 1000: loss 2.294256
# iteration 300 / 1000: loss 2.232947
# iteration 400 / 1000: loss 2.134602
# iteration 500 / 1000: loss 2.131911
# iteration 600 / 1000: loss 2.098779
# iteration 700 / 1000: loss 2.035039
# iteration 800 / 1000: loss 2.087666
# iteration 900 / 1000: loss 1.960447
# for hidden_size: 100, learning_rate: 1.000000e-04, regularisation strength: 0.250000, and epochs: 1000, the validation accuracy is: 0.285000
# iteration 0 / 1500: loss 2.303345
# iteration 100 / 1500: loss 2.302375
# iteration 200 / 1500: loss 2.294491
# iteration 300 / 1500: loss 2.251455
# iteration 400 / 1500: loss 2.148276
# iteration 500 / 1500: loss 2.159784
# iteration 600 / 1500: loss 2.063777
# iteration 700 / 1500: loss 2.031715
# iteration 800 / 1500: loss 1.985047
# iteration 900 / 1500: loss 1.930988
# iteration 1000 / 1500: loss 1.936902
# iteration 1100 / 1500: loss 1.894684
# iteration 1200 / 1500: loss 1.885729
# iteration 1300 / 1500: loss 1.881429
# iteration 1400 / 1500: loss 1.901865
# for hidden_size: 100, learning_rate: 1.000000e-04, regularisation strength: 0.250000, and epochs: 1500, the validation accuracy is: 0.331000
# iteration 0 / 100: loss 2.303811
# for hidden_size: 100, learning_rate: 1.000000e-04, regularisation strength: 0.400000, and epochs: 100, the validation accuracy is: 0.104000
# iteration 0 / 500: loss 2.303794
# iteration 100 / 500: loss 2.302825
# iteration 200 / 500: loss 2.297179
# iteration 300 / 500: loss 2.235027
# iteration 400 / 500: loss 2.179836
# for hidden_size: 100, learning_rate: 1.000000e-04, regularisation strength: 0.400000, and epochs: 500, the validation accuracy is: 0.231000
# iteration 0 / 1000: loss 2.303797
# iteration 100 / 1000: loss 2.303119
# iteration 200 / 1000: loss 2.297171
# iteration 300 / 1000: loss 2.255020
# iteration 400 / 1000: loss 2.191139
# iteration 500 / 1000: loss 2.112958
# iteration 600 / 1000: loss 2.045443
# iteration 700 / 1000: loss 2.105135
# iteration 800 / 1000: loss 2.027330
# iteration 900 / 1000: loss 1.854324
# for hidden_size: 100, learning_rate: 1.000000e-04, regularisation strength: 0.400000, and epochs: 1000, the validation accuracy is: 0.295000
# iteration 0 / 1500: loss 2.303841
# iteration 100 / 1500: loss 2.302983
# iteration 200 / 1500: loss 2.295278
# iteration 300 / 1500: loss 2.239329
# iteration 400 / 1500: loss 2.187636
# iteration 500 / 1500: loss 2.151368
# iteration 600 / 1500: loss 2.048560
# iteration 700 / 1500: loss 1.978874
# iteration 800 / 1500: loss 1.991678
# iteration 900 / 1500: loss 2.009033
# iteration 1000 / 1500: loss 1.932450
# iteration 1100 / 1500: loss 1.959391
# iteration 1200 / 1500: loss 1.871791
# iteration 1300 / 1500: loss 2.009767
# iteration 1400 / 1500: loss 1.846296
# for hidden_size: 100, learning_rate: 1.000000e-04, regularisation strength: 0.400000, and epochs: 1500, the validation accuracy is: 0.334000
# iteration 0 / 100: loss 2.303060
# for hidden_size: 150, learning_rate: 1.000000e-03, regularisation strength: 0.100000, and epochs: 100, the validation accuracy is: 0.134000
# iteration 0 / 500: loss 2.302993
# iteration 100 / 500: loss 1.869713
# iteration 200 / 500: loss 1.649603
# iteration 300 / 500: loss 1.680435
# iteration 400 / 500: loss 1.686230
# for hidden_size: 150, learning_rate: 1.000000e-03, regularisation strength: 0.100000, and epochs: 500, the validation accuracy is: 0.457000
# iteration 0 / 1000: loss 2.303017
# iteration 100 / 1000: loss 1.947067
# iteration 200 / 1000: loss 1.770151
# iteration 300 / 1000: loss 1.701852
# iteration 400 / 1000: loss 1.581049
# iteration 500 / 1000: loss 1.535575
# iteration 600 / 1000: loss 1.572894
# iteration 700 / 1000: loss 1.491960
# iteration 800 / 1000: loss 1.394812
# iteration 900 / 1000: loss 1.406431
# for hidden_size: 150, learning_rate: 1.000000e-03, regularisation strength: 0.100000, and epochs: 1000, the validation accuracy is: 0.447000
# iteration 0 / 1500: loss 2.303064
# iteration 100 / 1500: loss 1.955080
# iteration 200 / 1500: loss 1.726856
# iteration 300 / 1500: loss 1.666007
# iteration 400 / 1500: loss 1.690670
# iteration 500 / 1500: loss 1.535332
# iteration 600 / 1500: loss 1.505658
# iteration 700 / 1500: loss 1.504089
# iteration 800 / 1500: loss 1.534689
# iteration 900 / 1500: loss 1.527464
# iteration 1000 / 1500: loss 1.413450
# iteration 1100 / 1500: loss 1.201990
# iteration 1200 / 1500: loss 1.314745
# iteration 1300 / 1500: loss 1.411392
# iteration 1400 / 1500: loss 1.399465
# for hidden_size: 150, learning_rate: 1.000000e-03, regularisation strength: 0.100000, and epochs: 1500, the validation accuracy is: 0.504000
# new best network!
# iteration 0 / 100: loss 2.303514
# for hidden_size: 150, learning_rate: 1.000000e-03, regularisation strength: 0.200000, and epochs: 100, the validation accuracy is: 0.155000
# iteration 0 / 500: loss 2.303484
# iteration 100 / 500: loss 1.963100
# iteration 200 / 500: loss 1.776813
# iteration 300 / 500: loss 1.677279
# iteration 400 / 500: loss 1.707040
# for hidden_size: 150, learning_rate: 1.000000e-03, regularisation strength: 0.200000, and epochs: 500, the validation accuracy is: 0.449000
# iteration 0 / 1000: loss 2.303514
# iteration 100 / 1000: loss 1.999835
# iteration 200 / 1000: loss 1.729894
# iteration 300 / 1000: loss 1.736862
# iteration 400 / 1000: loss 1.494271
# iteration 500 / 1000: loss 1.550654
# iteration 600 / 1000: loss 1.503273
# iteration 700 / 1000: loss 1.644935
# iteration 800 / 1000: loss 1.510863
# iteration 900 / 1000: loss 1.621789
# for hidden_size: 150, learning_rate: 1.000000e-03, regularisation strength: 0.200000, and epochs: 1000, the validation accuracy is: 0.498000
# iteration 0 / 1500: loss 2.303538
# iteration 100 / 1500: loss 1.902838
# iteration 200 / 1500: loss 1.845435
# iteration 300 / 1500: loss 1.654672
# iteration 400 / 1500: loss 1.560111
# iteration 500 / 1500: loss 1.632750
# iteration 600 / 1500: loss 1.537097
# iteration 700 / 1500: loss 1.550872
# iteration 800 / 1500: loss 1.467071
# iteration 900 / 1500: loss 1.455420
# iteration 1000 / 1500: loss 1.599195
# iteration 1100 / 1500: loss 1.483956
# iteration 1200 / 1500: loss 1.510989
# iteration 1300 / 1500: loss 1.270019
# iteration 1400 / 1500: loss 1.372374
# for hidden_size: 150, learning_rate: 1.000000e-03, regularisation strength: 0.200000, and epochs: 1500, the validation accuracy is: 0.498000
# iteration 0 / 100: loss 2.303748
# for hidden_size: 150, learning_rate: 1.000000e-03, regularisation strength: 0.250000, and epochs: 100, the validation accuracy is: 0.155000
# iteration 0 / 500: loss 2.303679
# iteration 100 / 500: loss 1.895324
# iteration 200 / 500: loss 1.736633
# iteration 300 / 500: loss 1.645404
# iteration 400 / 500: loss 1.705973
# for hidden_size: 150, learning_rate: 1.000000e-03, regularisation strength: 0.250000, and epochs: 500, the validation accuracy is: 0.444000
# iteration 0 / 1000: loss 2.303706
# iteration 100 / 1000: loss 1.901087
# iteration 200 / 1000: loss 1.872045
# iteration 300 / 1000: loss 1.687120
# iteration 400 / 1000: loss 1.604802
# iteration 500 / 1000: loss 1.750298
# iteration 600 / 1000: loss 1.494901
# iteration 700 / 1000: loss 1.667679
# iteration 800 / 1000: loss 1.574591
# iteration 900 / 1000: loss 1.527843
# for hidden_size: 150, learning_rate: 1.000000e-03, regularisation strength: 0.250000, and epochs: 1000, the validation accuracy is: 0.487000
# iteration 0 / 1500: loss 2.303715
# iteration 100 / 1500: loss 1.879720
# iteration 200 / 1500: loss 1.655249
# iteration 300 / 1500: loss 1.717859
# iteration 400 / 1500: loss 1.575441
# iteration 500 / 1500: loss 1.505608
# iteration 600 / 1500: loss 1.543624
# iteration 700 / 1500: loss 1.452874
# iteration 800 / 1500: loss 1.429710
# iteration 900 / 1500: loss 1.414961
# iteration 1000 / 1500: loss 1.464725
# iteration 1100 / 1500: loss 1.457836
# iteration 1200 / 1500: loss 1.499421
# iteration 1300 / 1500: loss 1.500328
# iteration 1400 / 1500: loss 1.413797
# for hidden_size: 150, learning_rate: 1.000000e-03, regularisation strength: 0.250000, and epochs: 1500, the validation accuracy is: 0.500000
# iteration 0 / 100: loss 2.304396
# for hidden_size: 150, learning_rate: 1.000000e-03, regularisation strength: 0.400000, and epochs: 100, the validation accuracy is: 0.153000
# iteration 0 / 500: loss 2.304395
# iteration 100 / 500: loss 1.911946
# iteration 200 / 500: loss 1.726924
# iteration 300 / 500: loss 1.709436
# iteration 400 / 500: loss 1.654331
# for hidden_size: 150, learning_rate: 1.000000e-03, regularisation strength: 0.400000, and epochs: 500, the validation accuracy is: 0.435000
# iteration 0 / 1000: loss 2.304443
# iteration 100 / 1000: loss 1.916430
# iteration 200 / 1000: loss 1.706337
# iteration 300 / 1000: loss 1.674567
# iteration 400 / 1000: loss 1.601380
# iteration 500 / 1000: loss 1.731581
# iteration 600 / 1000: loss 1.528874
# iteration 700 / 1000: loss 1.652357
# iteration 800 / 1000: loss 1.562904
# iteration 900 / 1000: loss 1.606313
# for hidden_size: 150, learning_rate: 1.000000e-03, regularisation strength: 0.400000, and epochs: 1000, the validation accuracy is: 0.489000
# iteration 0 / 1500: loss 2.304366
# iteration 100 / 1500: loss 1.896607
# iteration 200 / 1500: loss 1.745268
# iteration 300 / 1500: loss 1.789854
# iteration 400 / 1500: loss 1.547361
# iteration 500 / 1500: loss 1.596348
# iteration 600 / 1500: loss 1.637523
# iteration 700 / 1500: loss 1.604723
# iteration 800 / 1500: loss 1.451818
# iteration 900 / 1500: loss 1.561727
# iteration 1000 / 1500: loss 1.617530
# iteration 1100 / 1500: loss 1.443540
# iteration 1200 / 1500: loss 1.561723
# iteration 1300 / 1500: loss 1.592673
# iteration 1400 / 1500: loss 1.496118
# for hidden_size: 150, learning_rate: 1.000000e-03, regularisation strength: 0.400000, and epochs: 1500, the validation accuracy is: 0.506000
# new best network!
# iteration 0 / 100: loss 2.302996
# for hidden_size: 150, learning_rate: 5.000000e-03, regularisation strength: 0.100000, and epochs: 100, the validation accuracy is: 0.140000
# iteration 0 / 500: loss 2.303060
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# for hidden_size: 150, learning_rate: 5.000000e-03, regularisation strength: 0.100000, and epochs: 500, the validation accuracy is: 0.087000
# iteration 0 / 1000: loss 2.303014
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# for hidden_size: 150, learning_rate: 5.000000e-03, regularisation strength: 0.100000, and epochs: 1000, the validation accuracy is: 0.087000
# iteration 0 / 1500: loss 2.303092
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# for hidden_size: 150, learning_rate: 5.000000e-03, regularisation strength: 0.100000, and epochs: 1500, the validation accuracy is: 0.087000
# iteration 0 / 100: loss 2.303577
# for hidden_size: 150, learning_rate: 5.000000e-03, regularisation strength: 0.200000, and epochs: 100, the validation accuracy is: 0.186000
# iteration 0 / 500: loss 2.303547
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# for hidden_size: 150, learning_rate: 5.000000e-03, regularisation strength: 0.200000, and epochs: 500, the validation accuracy is: 0.087000
# iteration 0 / 1000: loss 2.303498
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# for hidden_size: 150, learning_rate: 5.000000e-03, regularisation strength: 0.200000, and epochs: 1000, the validation accuracy is: 0.087000
# iteration 0 / 1500: loss 2.303498
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# for hidden_size: 150, learning_rate: 5.000000e-03, regularisation strength: 0.200000, and epochs: 1500, the validation accuracy is: 0.087000
# iteration 0 / 100: loss 2.303716
# for hidden_size: 150, learning_rate: 5.000000e-03, regularisation strength: 0.250000, and epochs: 100, the validation accuracy is: 0.153000
# iteration 0 / 500: loss 2.303714
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# for hidden_size: 150, learning_rate: 5.000000e-03, regularisation strength: 0.250000, and epochs: 500, the validation accuracy is: 0.087000
# iteration 0 / 1000: loss 2.303713
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# for hidden_size: 150, learning_rate: 5.000000e-03, regularisation strength: 0.250000, and epochs: 1000, the validation accuracy is: 0.087000
# iteration 0 / 1500: loss 2.303717
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# for hidden_size: 150, learning_rate: 5.000000e-03, regularisation strength: 0.250000, and epochs: 1500, the validation accuracy is: 0.087000
# iteration 0 / 100: loss 2.304411
# for hidden_size: 150, learning_rate: 5.000000e-03, regularisation strength: 0.400000, and epochs: 100, the validation accuracy is: 0.212000
# iteration 0 / 500: loss 2.304459
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# for hidden_size: 150, learning_rate: 5.000000e-03, regularisation strength: 0.400000, and epochs: 500, the validation accuracy is: 0.087000
# iteration 0 / 1000: loss 2.304483
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# for hidden_size: 150, learning_rate: 5.000000e-03, regularisation strength: 0.400000, and epochs: 1000, the validation accuracy is: 0.087000
# iteration 0 / 1500: loss 2.304449
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# for hidden_size: 150, learning_rate: 5.000000e-03, regularisation strength: 0.400000, and epochs: 1500, the validation accuracy is: 0.087000
# iteration 0 / 100: loss 2.303057
# for hidden_size: 150, learning_rate: 1.000000e-04, regularisation strength: 0.100000, and epochs: 100, the validation accuracy is: 0.091000
# iteration 0 / 500: loss 2.303040
# iteration 100 / 500: loss 2.301651
# iteration 200 / 500: loss 2.287312
# iteration 300 / 500: loss 2.215198
# iteration 400 / 500: loss 2.126396
# for hidden_size: 150, learning_rate: 1.000000e-04, regularisation strength: 0.100000, and epochs: 500, the validation accuracy is: 0.241000
# iteration 0 / 1000: loss 2.303044
# iteration 100 / 1000: loss 2.301341
# iteration 200 / 1000: loss 2.291867
# iteration 300 / 1000: loss 2.230504
# iteration 400 / 1000: loss 2.154442
# iteration 500 / 1000: loss 2.080686
# iteration 600 / 1000: loss 2.066048
# iteration 700 / 1000: loss 2.028336
# iteration 800 / 1000: loss 1.929056
# iteration 900 / 1000: loss 2.005939
# for hidden_size: 150, learning_rate: 1.000000e-04, regularisation strength: 0.100000, and epochs: 1000, the validation accuracy is: 0.306000
# iteration 0 / 1500: loss 2.303072
# iteration 100 / 1500: loss 2.301832
# iteration 200 / 1500: loss 2.291549
# iteration 300 / 1500: loss 2.242668
# iteration 400 / 1500: loss 2.174530
# iteration 500 / 1500: loss 2.092981
# iteration 600 / 1500: loss 2.011332
# iteration 700 / 1500: loss 2.033325
# iteration 800 / 1500: loss 1.981117
# iteration 900 / 1500: loss 1.937288
# iteration 1000 / 1500: loss 1.959514
# iteration 1100 / 1500: loss 1.946724
# iteration 1200 / 1500: loss 1.943218
# iteration 1300 / 1500: loss 1.848000
# iteration 1400 / 1500: loss 1.868559
# for hidden_size: 150, learning_rate: 1.000000e-04, regularisation strength: 0.100000, and epochs: 1500, the validation accuracy is: 0.338000
# iteration 0 / 100: loss 2.303558
# for hidden_size: 150, learning_rate: 1.000000e-04, regularisation strength: 0.200000, and epochs: 100, the validation accuracy is: 0.072000
# iteration 0 / 500: loss 2.303509
# iteration 100 / 500: loss 2.302390
# iteration 200 / 500: loss 2.287697
# iteration 300 / 500: loss 2.226885
# iteration 400 / 500: loss 2.182745
# for hidden_size: 150, learning_rate: 1.000000e-04, regularisation strength: 0.200000, and epochs: 500, the validation accuracy is: 0.237000
# iteration 0 / 1000: loss 2.303536
# iteration 100 / 1000: loss 2.302208
# iteration 200 / 1000: loss 2.288697
# iteration 300 / 1000: loss 2.235876
# iteration 400 / 1000: loss 2.183895
# iteration 500 / 1000: loss 2.080125
# iteration 600 / 1000: loss 2.049945
# iteration 700 / 1000: loss 1.965286
# iteration 800 / 1000: loss 1.943204
# iteration 900 / 1000: loss 1.945574
# for hidden_size: 150, learning_rate: 1.000000e-04, regularisation strength: 0.200000, and epochs: 1000, the validation accuracy is: 0.297000
# iteration 0 / 1500: loss 2.303510
# iteration 100 / 1500: loss 2.302222
# iteration 200 / 1500: loss 2.285485
# iteration 300 / 1500: loss 2.227426
# iteration 400 / 1500: loss 2.143328
# iteration 500 / 1500: loss 2.111652
# iteration 600 / 1500: loss 2.037499
# iteration 700 / 1500: loss 2.075161
# iteration 800 / 1500: loss 1.993268
# iteration 900 / 1500: loss 2.009616
# iteration 1000 / 1500: loss 1.904003
# iteration 1100 / 1500: loss 1.922964
# iteration 1200 / 1500: loss 1.951470
# iteration 1300 / 1500: loss 1.903736
# iteration 1400 / 1500: loss 1.781240
# for hidden_size: 150, learning_rate: 1.000000e-04, regularisation strength: 0.200000, and epochs: 1500, the validation accuracy is: 0.342000
# iteration 0 / 100: loss 2.303753
# for hidden_size: 150, learning_rate: 1.000000e-04, regularisation strength: 0.250000, and epochs: 100, the validation accuracy is: 0.097000
# iteration 0 / 500: loss 2.303711
# iteration 100 / 500: loss 2.301841
# iteration 200 / 500: loss 2.284194
# iteration 300 / 500: loss 2.212109
# iteration 400 / 500: loss 2.149944
# for hidden_size: 150, learning_rate: 1.000000e-04, regularisation strength: 0.250000, and epochs: 500, the validation accuracy is: 0.238000
# iteration 0 / 1000: loss 2.303715
# iteration 100 / 1000: loss 2.302117
# iteration 200 / 1000: loss 2.291361
# iteration 300 / 1000: loss 2.224866
# iteration 400 / 1000: loss 2.160082
# iteration 500 / 1000: loss 2.082974
# iteration 600 / 1000: loss 2.043472
# iteration 700 / 1000: loss 1.967087
# iteration 800 / 1000: loss 1.998115
# iteration 900 / 1000: loss 1.961812
# for hidden_size: 150, learning_rate: 1.000000e-04, regularisation strength: 0.250000, and epochs: 1000, the validation accuracy is: 0.300000
# iteration 0 / 1500: loss 2.303727
# iteration 100 / 1500: loss 2.302273
# iteration 200 / 1500: loss 2.291333
# iteration 300 / 1500: loss 2.225527
# iteration 400 / 1500: loss 2.099683
# iteration 500 / 1500: loss 2.119868
# iteration 600 / 1500: loss 1.989341
# iteration 700 / 1500: loss 1.967659
# iteration 800 / 1500: loss 2.000805
# iteration 900 / 1500: loss 2.022107
# iteration 1000 / 1500: loss 2.024504
# iteration 1100 / 1500: loss 2.015104
# iteration 1200 / 1500: loss 1.899828
# iteration 1300 / 1500: loss 1.884406
# iteration 1400 / 1500: loss 1.748926
# for hidden_size: 150, learning_rate: 1.000000e-04, regularisation strength: 0.250000, and epochs: 1500, the validation accuracy is: 0.337000
# iteration 0 / 100: loss 2.304408
# for hidden_size: 150, learning_rate: 1.000000e-04, regularisation strength: 0.400000, and epochs: 100, the validation accuracy is: 0.101000
# iteration 0 / 500: loss 2.304459
# iteration 100 / 500: loss 2.303394
# iteration 200 / 500: loss 2.293668
# iteration 300 / 500: loss 2.258847
# iteration 400 / 500: loss 2.129350
# for hidden_size: 150, learning_rate: 1.000000e-04, regularisation strength: 0.400000, and epochs: 500, the validation accuracy is: 0.239000
# iteration 0 / 1000: loss 2.304393
# iteration 100 / 1000: loss 2.303112
# iteration 200 / 1000: loss 2.290216
# iteration 300 / 1000: loss 2.232194
# iteration 400 / 1000: loss 2.158139
# iteration 500 / 1000: loss 2.056654
# iteration 600 / 1000: loss 2.054542
# iteration 700 / 1000: loss 2.038328
# iteration 800 / 1000: loss 1.992958
# iteration 900 / 1000: loss 1.941911
# for hidden_size: 150, learning_rate: 1.000000e-04, regularisation strength: 0.400000, and epochs: 1000, the validation accuracy is: 0.296000
# iteration 0 / 1500: loss 2.304398
# iteration 100 / 1500: loss 2.303065
# iteration 200 / 1500: loss 2.290435
# iteration 300 / 1500: loss 2.236603
# iteration 400 / 1500: loss 2.175209
# iteration 500 / 1500: loss 2.043199
# iteration 600 / 1500: loss 2.012042
# iteration 700 / 1500: loss 2.051674
# iteration 800 / 1500: loss 1.903453
# iteration 900 / 1500: loss 1.895206
# iteration 1000 / 1500: loss 1.855577
# iteration 1100 / 1500: loss 1.967441
# iteration 1200 / 1500: loss 1.870344
# iteration 1300 / 1500: loss 1.926319
# iteration 1400 / 1500: loss 1.836690
# for hidden_size: 150, learning_rate: 1.000000e-04, regularisation strength: 0.400000, and epochs: 1500, the validation accuracy is: 0.333000
# iteration 0 / 100: loss 2.304146
# for hidden_size: 500, learning_rate: 1.000000e-03, regularisation strength: 0.100000, and epochs: 100, the validation accuracy is: 0.184000
# iteration 0 / 500: loss 2.304079
# iteration 100 / 500: loss 1.832143
# iteration 200 / 500: loss 1.788996
# iteration 300 / 500: loss 1.674636
# iteration 400 / 500: loss 1.577205
# for hidden_size: 500, learning_rate: 1.000000e-03, regularisation strength: 0.100000, and epochs: 500, the validation accuracy is: 0.463000
# iteration 0 / 1000: loss 2.304200
# iteration 100 / 1000: loss 1.786279
# iteration 200 / 1000: loss 1.766208
# iteration 300 / 1000: loss 1.709613
# iteration 400 / 1000: loss 1.601003
# iteration 500 / 1000: loss 1.492780
# iteration 600 / 1000: loss 1.464366
# iteration 700 / 1000: loss 1.524118
# iteration 800 / 1000: loss 1.318470
# iteration 900 / 1000: loss 1.346348
# for hidden_size: 500, learning_rate: 1.000000e-03, regularisation strength: 0.100000, and epochs: 1000, the validation accuracy is: 0.499000
# iteration 0 / 1500: loss 2.304224
# iteration 100 / 1500: loss 1.861795
# iteration 200 / 1500: loss 1.768457
# iteration 300 / 1500: loss 1.671285
# iteration 400 / 1500: loss 1.560086
# iteration 500 / 1500: loss 1.524391
# iteration 600 / 1500: loss 1.536410
# iteration 700 / 1500: loss 1.414866
# iteration 800 / 1500: loss 1.467948
# iteration 900 / 1500: loss 1.443392
# iteration 1000 / 1500: loss 1.461464
# iteration 1100 / 1500: loss 1.462178
# iteration 1200 / 1500: loss 1.375902
# iteration 1300 / 1500: loss 1.332473
# iteration 1400 / 1500: loss 1.398814
# for hidden_size: 500, learning_rate: 1.000000e-03, regularisation strength: 0.100000, and epochs: 1500, the validation accuracy is: 0.501000
# iteration 0 / 100: loss 2.305637
# for hidden_size: 500, learning_rate: 1.000000e-03, regularisation strength: 0.200000, and epochs: 100, the validation accuracy is: 0.139000
# iteration 0 / 500: loss 2.305626
# iteration 100 / 500: loss 1.956323
# iteration 200 / 500: loss 1.610646
# iteration 300 / 500: loss 1.654670
# iteration 400 / 500: loss 1.583377
# for hidden_size: 500, learning_rate: 1.000000e-03, regularisation strength: 0.200000, and epochs: 500, the validation accuracy is: 0.442000
# iteration 0 / 1000: loss 2.305713
# iteration 100 / 1000: loss 1.869696
# iteration 200 / 1000: loss 1.773527
# iteration 300 / 1000: loss 1.680050
# iteration 400 / 1000: loss 1.478011
# iteration 500 / 1000: loss 1.576487
# iteration 600 / 1000: loss 1.455228
# iteration 700 / 1000: loss 1.434429
# iteration 800 / 1000: loss 1.661998
# iteration 900 / 1000: loss 1.364938
# for hidden_size: 500, learning_rate: 1.000000e-03, regularisation strength: 0.200000, and epochs: 1000, the validation accuracy is: 0.489000
# iteration 0 / 1500: loss 2.305699
# iteration 100 / 1500: loss 1.867222
# iteration 200 / 1500: loss 1.789469
# iteration 300 / 1500: loss 1.658368
# iteration 400 / 1500: loss 1.583457
# iteration 500 / 1500: loss 1.601655
# iteration 600 / 1500: loss 1.368587
# iteration 700 / 1500: loss 1.470659
# iteration 800 / 1500: loss 1.517422
# iteration 900 / 1500: loss 1.450601
# iteration 1000 / 1500: loss 1.492256
# iteration 1100 / 1500: loss 1.531208
# iteration 1200 / 1500: loss 1.348144
# iteration 1300 / 1500: loss 1.518152
# iteration 1400 / 1500: loss 1.381766
# for hidden_size: 500, learning_rate: 1.000000e-03, regularisation strength: 0.200000, and epochs: 1500, the validation accuracy is: 0.517000
# new best network!
# iteration 0 / 100: loss 2.306415
# for hidden_size: 500, learning_rate: 1.000000e-03, regularisation strength: 0.250000, and epochs: 100, the validation accuracy is: 0.161000
# iteration 0 / 500: loss 2.306346
# iteration 100 / 500: loss 1.898453
# iteration 200 / 500: loss 1.751381
# iteration 300 / 500: loss 1.624735
# iteration 400 / 500: loss 1.719342
# for hidden_size: 500, learning_rate: 1.000000e-03, regularisation strength: 0.250000, and epochs: 500, the validation accuracy is: 0.460000
# iteration 0 / 1000: loss 2.306351
# iteration 100 / 1000: loss 1.929250
# iteration 200 / 1000: loss 1.722906
# iteration 300 / 1000: loss 1.740991
# iteration 400 / 1000: loss 1.523832
# iteration 500 / 1000: loss 1.488648
# iteration 600 / 1000: loss 1.549194
# iteration 700 / 1000: loss 1.522988
# iteration 800 / 1000: loss 1.513153
# iteration 900 / 1000: loss 1.374238
# for hidden_size: 500, learning_rate: 1.000000e-03, regularisation strength: 0.250000, and epochs: 1000, the validation accuracy is: 0.482000
# iteration 0 / 1500: loss 2.306440
# iteration 100 / 1500: loss 1.916158
# iteration 200 / 1500: loss 1.748454
# iteration 300 / 1500: loss 1.604929
# iteration 400 / 1500: loss 1.664338
# iteration 500 / 1500: loss 1.611497
# iteration 600 / 1500: loss 1.596459
# iteration 700 / 1500: loss 1.372679
# iteration 800 / 1500: loss 1.601522
# iteration 900 / 1500: loss 1.493951
# iteration 1000 / 1500: loss 1.406528
# iteration 1100 / 1500: loss 1.371593
# iteration 1200 / 1500: loss 1.459409
# iteration 1300 / 1500: loss 1.453030
# iteration 1400 / 1500: loss 1.470974
# for hidden_size: 500, learning_rate: 1.000000e-03, regularisation strength: 0.250000, and epochs: 1500, the validation accuracy is: 0.492000
# iteration 0 / 100: loss 2.308779
# for hidden_size: 500, learning_rate: 1.000000e-03, regularisation strength: 0.400000, and epochs: 100, the validation accuracy is: 0.175000
# iteration 0 / 500: loss 2.308762
# iteration 100 / 500: loss 1.768379
# iteration 200 / 500: loss 1.814380
# iteration 300 / 500: loss 1.601679
# iteration 400 / 500: loss 1.640861
# for hidden_size: 500, learning_rate: 1.000000e-03, regularisation strength: 0.400000, and epochs: 500, the validation accuracy is: 0.463000
# iteration 0 / 1000: loss 2.308730
# iteration 100 / 1000: loss 1.822571
# iteration 200 / 1000: loss 1.779603
# iteration 300 / 1000: loss 1.737325
# iteration 400 / 1000: loss 1.664594
# iteration 500 / 1000: loss 1.589049
# iteration 600 / 1000: loss 1.475240
# iteration 700 / 1000: loss 1.524785
# iteration 800 / 1000: loss 1.529042
# iteration 900 / 1000: loss 1.529366
# for hidden_size: 500, learning_rate: 1.000000e-03, regularisation strength: 0.400000, and epochs: 1000, the validation accuracy is: 0.478000
# iteration 0 / 1500: loss 2.308909
# iteration 100 / 1500: loss 1.860716
# iteration 200 / 1500: loss 1.714812
# iteration 300 / 1500: loss 1.725506
# iteration 400 / 1500: loss 1.660426
# iteration 500 / 1500: loss 1.640012
# iteration 600 / 1500: loss 1.531671
# iteration 700 / 1500: loss 1.580049
# iteration 800 / 1500: loss 1.544515
# iteration 900 / 1500: loss 1.596105
# iteration 1000 / 1500: loss 1.591800
# iteration 1100 / 1500: loss 1.494328
# iteration 1200 / 1500: loss 1.483102
# iteration 1300 / 1500: loss 1.501156
# iteration 1400 / 1500: loss 1.355906
# for hidden_size: 500, learning_rate: 1.000000e-03, regularisation strength: 0.400000, and epochs: 1500, the validation accuracy is: 0.509000
# iteration 0 / 100: loss 2.304056
# for hidden_size: 500, learning_rate: 5.000000e-03, regularisation strength: 0.100000, and epochs: 100, the validation accuracy is: 0.151000
# iteration 0 / 500: loss 2.304125
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# for hidden_size: 500, learning_rate: 5.000000e-03, regularisation strength: 0.100000, and epochs: 500, the validation accuracy is: 0.087000
# iteration 0 / 1000: loss 2.304156
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# for hidden_size: 500, learning_rate: 5.000000e-03, regularisation strength: 0.100000, and epochs: 1000, the validation accuracy is: 0.087000
# iteration 0 / 1500: loss 2.304052
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# for hidden_size: 500, learning_rate: 5.000000e-03, regularisation strength: 0.100000, and epochs: 1500, the validation accuracy is: 0.087000
# iteration 0 / 100: loss 2.305699
# for hidden_size: 500, learning_rate: 5.000000e-03, regularisation strength: 0.200000, and epochs: 100, the validation accuracy is: 0.194000
# iteration 0 / 500: loss 2.305721
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# for hidden_size: 500, learning_rate: 5.000000e-03, regularisation strength: 0.200000, and epochs: 500, the validation accuracy is: 0.087000
# iteration 0 / 1000: loss 2.305754
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# for hidden_size: 500, learning_rate: 5.000000e-03, regularisation strength: 0.200000, and epochs: 1000, the validation accuracy is: 0.087000
# iteration 0 / 1500: loss 2.305751
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# for hidden_size: 500, learning_rate: 5.000000e-03, regularisation strength: 0.200000, and epochs: 1500, the validation accuracy is: 0.087000
# iteration 0 / 100: loss 2.306407
# for hidden_size: 500, learning_rate: 5.000000e-03, regularisation strength: 0.250000, and epochs: 100, the validation accuracy is: 0.159000
# iteration 0 / 500: loss 2.306379
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# for hidden_size: 500, learning_rate: 5.000000e-03, regularisation strength: 0.250000, and epochs: 500, the validation accuracy is: 0.087000
# iteration 0 / 1000: loss 2.306414
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# for hidden_size: 500, learning_rate: 5.000000e-03, regularisation strength: 0.250000, and epochs: 1000, the validation accuracy is: 0.087000
# iteration 0 / 1500: loss 2.306541
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# for hidden_size: 500, learning_rate: 5.000000e-03, regularisation strength: 0.250000, and epochs: 1500, the validation accuracy is: 0.087000
# iteration 0 / 100: loss 2.308765
# for hidden_size: 500, learning_rate: 5.000000e-03, regularisation strength: 0.400000, and epochs: 100, the validation accuracy is: 0.224000
# iteration 0 / 500: loss 2.308725
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# for hidden_size: 500, learning_rate: 5.000000e-03, regularisation strength: 0.400000, and epochs: 500, the validation accuracy is: 0.087000
# iteration 0 / 1000: loss 2.308807
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# for hidden_size: 500, learning_rate: 5.000000e-03, regularisation strength: 0.400000, and epochs: 1000, the validation accuracy is: 0.087000
# iteration 0 / 1500: loss 2.308748
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# for hidden_size: 500, learning_rate: 5.000000e-03, regularisation strength: 0.400000, and epochs: 1500, the validation accuracy is: 0.087000
# iteration 0 / 100: loss 2.304047
# for hidden_size: 500, learning_rate: 1.000000e-04, regularisation strength: 0.100000, and epochs: 100, the validation accuracy is: 0.105000
# iteration 0 / 500: loss 2.304169
# iteration 100 / 500: loss 2.299571
# iteration 200 / 500: loss 2.252460
# iteration 300 / 500: loss 2.225549
# iteration 400 / 500: loss 2.070036
# for hidden_size: 500, learning_rate: 1.000000e-04, regularisation strength: 0.100000, and epochs: 500, the validation accuracy is: 0.262000
# iteration 0 / 1000: loss 2.304158
# iteration 100 / 1000: loss 2.300370
# iteration 200 / 1000: loss 2.265778
# iteration 300 / 1000: loss 2.225101
# iteration 400 / 1000: loss 2.133195
# iteration 500 / 1000: loss 2.081368
# iteration 600 / 1000: loss 1.911600
# iteration 700 / 1000: loss 1.979799
# iteration 800 / 1000: loss 1.990423
# iteration 900 / 1000: loss 1.963567
# for hidden_size: 500, learning_rate: 1.000000e-04, regularisation strength: 0.100000, and epochs: 1000, the validation accuracy is: 0.315000
# iteration 0 / 1500: loss 2.304210
# iteration 100 / 1500: loss 2.300300
# iteration 200 / 1500: loss 2.233821
# iteration 300 / 1500: loss 2.166648
# iteration 400 / 1500: loss 2.081407
# iteration 500 / 1500: loss 2.065392
# iteration 600 / 1500: loss 1.937846
# iteration 700 / 1500: loss 1.995141
# iteration 800 / 1500: loss 2.004100
# iteration 900 / 1500: loss 1.879778
# iteration 1000 / 1500: loss 1.952212
# iteration 1100 / 1500: loss 1.766011
# iteration 1200 / 1500: loss 1.875075
# iteration 1300 / 1500: loss 1.859751
# iteration 1400 / 1500: loss 1.839210
# for hidden_size: 500, learning_rate: 1.000000e-04, regularisation strength: 0.100000, and epochs: 1500, the validation accuracy is: 0.355000
# iteration 0 / 100: loss 2.305676
# for hidden_size: 500, learning_rate: 1.000000e-04, regularisation strength: 0.200000, and epochs: 100, the validation accuracy is: 0.100000
# iteration 0 / 500: loss 2.305632
# iteration 100 / 500: loss 2.300454
# iteration 200 / 500: loss 2.255315
# iteration 300 / 500: loss 2.192304
# iteration 400 / 500: loss 2.145481
# for hidden_size: 500, learning_rate: 1.000000e-04, regularisation strength: 0.200000, and epochs: 500, the validation accuracy is: 0.261000
# iteration 0 / 1000: loss 2.305698
# iteration 100 / 1000: loss 2.302326
# iteration 200 / 1000: loss 2.264386
# iteration 300 / 1000: loss 2.176802
# iteration 400 / 1000: loss 2.120954
# iteration 500 / 1000: loss 2.053673
# iteration 600 / 1000: loss 2.021531
# iteration 700 / 1000: loss 1.963094
# iteration 800 / 1000: loss 1.887559
# iteration 900 / 1000: loss 1.847009
# for hidden_size: 500, learning_rate: 1.000000e-04, regularisation strength: 0.200000, and epochs: 1000, the validation accuracy is: 0.318000
# iteration 0 / 1500: loss 2.305684
# iteration 100 / 1500: loss 2.301943
# iteration 200 / 1500: loss 2.267086
# iteration 300 / 1500: loss 2.172391
# iteration 400 / 1500: loss 2.044041
# iteration 500 / 1500: loss 2.051531
# iteration 600 / 1500: loss 1.988374
# iteration 700 / 1500: loss 1.964469
# iteration 800 / 1500: loss 1.900295
# iteration 900 / 1500: loss 1.920019
# iteration 1000 / 1500: loss 1.921310
# iteration 1100 / 1500: loss 1.861353
# iteration 1200 / 1500: loss 1.873863
# iteration 1300 / 1500: loss 1.885454
# iteration 1400 / 1500: loss 1.865628
# for hidden_size: 500, learning_rate: 1.000000e-04, regularisation strength: 0.200000, and epochs: 1500, the validation accuracy is: 0.357000
# iteration 0 / 100: loss 2.306483
# for hidden_size: 500, learning_rate: 1.000000e-04, regularisation strength: 0.250000, and epochs: 100, the validation accuracy is: 0.091000
# iteration 0 / 500: loss 2.306460
# iteration 100 / 500: loss 2.302172
# iteration 200 / 500: loss 2.261667
# iteration 300 / 500: loss 2.197656
# iteration 400 / 500: loss 2.078503
# for hidden_size: 500, learning_rate: 1.000000e-04, regularisation strength: 0.250000, and epochs: 500, the validation accuracy is: 0.254000
# iteration 0 / 1000: loss 2.306390
# iteration 100 / 1000: loss 2.301284
# iteration 200 / 1000: loss 2.273007
# iteration 300 / 1000: loss 2.142275
# iteration 400 / 1000: loss 2.152657
# iteration 500 / 1000: loss 2.015541
# iteration 600 / 1000: loss 2.055903
# iteration 700 / 1000: loss 2.092845
# iteration 800 / 1000: loss 1.975439
# iteration 900 / 1000: loss 1.864616
# for hidden_size: 500, learning_rate: 1.000000e-04, regularisation strength: 0.250000, and epochs: 1000, the validation accuracy is: 0.314000
# iteration 0 / 1500: loss 2.306437
# iteration 100 / 1500: loss 2.301871
# iteration 200 / 1500: loss 2.278706
# iteration 300 / 1500: loss 2.181209
# iteration 400 / 1500: loss 2.095818
# iteration 500 / 1500: loss 2.081837
# iteration 600 / 1500: loss 2.077347
# iteration 700 / 1500: loss 1.972476
# iteration 800 / 1500: loss 1.943120
# iteration 900 / 1500: loss 1.910255
# iteration 1000 / 1500: loss 1.809103
# iteration 1100 / 1500: loss 1.976462
# iteration 1200 / 1500: loss 1.834666
# iteration 1300 / 1500: loss 1.889739
# iteration 1400 / 1500: loss 1.868037
# for hidden_size: 500, learning_rate: 1.000000e-04, regularisation strength: 0.250000, and epochs: 1500, the validation accuracy is: 0.353000
# iteration 0 / 100: loss 2.308758
# for hidden_size: 500, learning_rate: 1.000000e-04, regularisation strength: 0.400000, and epochs: 100, the validation accuracy is: 0.117000
# iteration 0 / 500: loss 2.308722
# iteration 100 / 500: loss 2.305142
# iteration 200 / 500: loss 2.274356
# iteration 300 / 500: loss 2.146071
# iteration 400 / 500: loss 2.120540
# for hidden_size: 500, learning_rate: 1.000000e-04, regularisation strength: 0.400000, and epochs: 500, the validation accuracy is: 0.253000
# iteration 0 / 1000: loss 2.308801
# iteration 100 / 1000: loss 2.304580
# iteration 200 / 1000: loss 2.281773
# iteration 300 / 1000: loss 2.189852
# iteration 400 / 1000: loss 2.125661
# iteration 500 / 1000: loss 2.042770
# iteration 600 / 1000: loss 2.050778
# iteration 700 / 1000: loss 1.924332
# iteration 800 / 1000: loss 1.961340
# iteration 900 / 1000: loss 1.994572
# for hidden_size: 500, learning_rate: 1.000000e-04, regularisation strength: 0.400000, and epochs: 1000, the validation accuracy is: 0.305000
# iteration 0 / 1500: loss 2.308836
# iteration 100 / 1500: loss 2.304962
# iteration 200 / 1500: loss 2.276029
# iteration 300 / 1500: loss 2.195599
# iteration 400 / 1500: loss 2.095517
# iteration 500 / 1500: loss 2.055079
# iteration 600 / 1500: loss 2.071315
# iteration 700 / 1500: loss 1.992625
# iteration 800 / 1500: loss 2.053133
# iteration 900 / 1500: loss 1.954858
# iteration 1000 / 1500: loss 1.918703
# iteration 1100 / 1500: loss 1.869076
# iteration 1200 / 1500: loss 1.849055
# iteration 1300 / 1500: loss 1.844992
# iteration 1400 / 1500: loss 1.949254
# for hidden_size: 500, learning_rate: 1.000000e-04, regularisation strength: 0.400000, and epochs: 1500, the validation accuracy is: 0.355000
# Best net: for hidden_size: 500, learning_rate: 1.000000e-03, regularisation strength: 0.200000, and epochs: 1500, the validation accuracy is: 0.517000

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.508

# %% [markdown]
# **Inline Question**
#
# Now that you have trained a Neural Network classifier, you may find that your testing accuracy is much lower than the training accuracy. In what ways can we decrease this gap? Select all that apply.
# 1. Train on a larger dataset.
# 2. Add more hidden units.
# 3. Increase the regularization strength.
# 4. None of the above.
#
# *Your answer*:
#
# *Your explanation:*
